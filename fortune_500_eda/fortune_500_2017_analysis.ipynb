# %% [markdown]
# # Fortune 500 (2017)
#
# GitHub: https://github.com/daikiminaki/
# LinkedIn: https://www.linkedin.com/in/daiki-minaki/
# Projects: https://www.daikiminaki.com/

# %%
#Import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()

# %% [markdown]
# ### About the Data
# Source: https://www.kaggle.com/vineetjaiswal/fortune500-2017

# %%
#Import Data
companies = pd.read_csv('fortune_2015_2017.csv')

# %%
#New columns names
companies.columns = ['rank', 'title', 'website', 'employees', 'sector', 'industry',\
       'hqlocation', 'hqaddr', 'hqcity', 'hqstate', 'hqzip', 'hqtel', 'ceo',\
       'ceo-title', 'address', 'ticker', 'fullname', 'revenues', 'revchange',\
       'profits', 'prftchange', 'assets', 'totshequity']

# %%
#Describing the Data
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
# rank           500 non-null int64
# title          500 non-null object
# website        500 non-null object
# employees      500 non-null int64
# sector         500 non-null object
# industry       500 non-null object
# hqlocation     500 non-null object
# hqaddr         500 non-null object
# hqcity         500 non-null object
# hqstate        500 non-null object
# hqzip          500 non-null int64
# hqtel          500 non-null object
# ceo            500 non-null object
# ceo-title      500 non-null object
# address        500 non-null object
# ticker         500 non-null object
# fullname       500 non-null object
# revenues       500 non-null int64
# revchange      500 non-null float64
# profits        500 non-null float64
# prftchange     500 non-null object
# assets         500 non-null int64
# totshequity    500 non-null float64
# dtypes: float64(3), int64(5), object(15)
# memory usage: 89.9+ KB

# %%
#Divide by 1000 to make units into $ 1 billion.
companies['revenues'] = companies['revenues'] / 1000

# %% [markdown]
# # By Sector

# %% [markdown]
# ## 1. Counts by Sectors

# %%
#Counts by Sector
counts_by_sector = companies.groupby('sector')[['employees']].count().reset_index()
counts_by_sector.columns = ['sector','count']

# %%
#Plot Total Assets by Sector
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='count', y='sector', data=counts_by_sector)
_ = plt.title('Company Counts by Sector', size=13)
_ = plt.xlabel('Count', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('1counts_by_sector.png')

# %% [markdown]
# ## 1. Assets by Sectors

# %%
#Sum by sector 
total_assets_by_sector = companies.groupby(['sector']).sum()[['assets']].reset_index()
total_assets_by_sector.columns = ['sector','total_assets']

# %%
#Merge New Feature
by_sector = counts_by_sector.merge(total_assets_by_sector)

# %% [markdown]
# ### a) Total Assets By Sector w/ Outlier

# %%
#Plot Total Assets by Sector
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_assets', y='sector', data=total_assets_by_sector)
_ = plt.title('Total Assets by Sector With Outlier', size=13)
_ = plt.xlabel('Assets', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('2total_assets_by_sector.png')

# %%
#Average by Sector and Industry
assets_by_industry = companies.groupby(['sector','industry'])[['assets']].mean().sort_values('assets', ascending=False).reset_index()
assets_by_industry.columns = ['sector','industry','count']

#Plot Company Count Barplot
_ = plt.figure(figsize=(10,7))
_ = sns.boxplot(x='count', y='sector', data=counts_by_industry)
_ = plt.title('Average Assets by Sector', size=13)
_ = plt.xlabel('Count', size=12)
_ = plt.ylabel('')

# %% [markdown]
# ### b) Total Assets by Sector w/o Outlier

# %%
#Total Assets Without Outlier
asset_without_outlier_sector = total_assets_by_sector[total_assets_by_sector.sector != 'Financials']
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_assets', y='sector', data=asset_without_outlier_sector)
_ = plt.title('Total Assets by Sector Without Outlier', size=13)
_ = plt.xlabel('Assets', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('3asset_without_outlier_sector.png')

# %%
#Average by Sector and Industry
assets_by_industry = companies.groupby(['sector','industry'])[['assets']].mean().sort_values('assets', ascending=False).reset_index()
assets_by_industry.columns = ['sector','industry','count']
asset_without_outlier_industry = assets_by_industry[assets_by_industry.sector != 'Financials']

#Plot Company Count Barplot
_ = plt.figure(figsize=(10,7))
_ = sns.boxplot(x='count', y='sector', data=asset_without_outlier_industry)
_ = plt.title('Average Assets by Sector and Industry', size=13)
_ = plt.xlabel('Average Assets', size=12)
_ = plt.ylabel('')

# %% [markdown]
# ### Question: How big is this outlier (The Financial Sector)?!?!?

# %%
#Percent Of All Assets
total_financial_assets = total_assets_by_sector[total_assets_by_sector.sector == 'Financials']['total_assets']
total_assets = total_assets_by_sector.sum()['total_assets']

print(total_financial_assets / total_assets)
# Out:
# 6    0.667168
# Name: total_assets, dtype: float64

# %% [markdown]
# #### Financial Sector Holds 66.7% Of All Assets Of The Fortune 500 Companies.

# %% [markdown]
# ### Answer: The Financial Sector has 2/3 of Assets all assets in the Fortune 500.

# %%
#Financial Sector Assets
financial_assets = total_assets_by_sector[total_assets_by_sector.sector == 'Financials']

#All Other Assets (Sum)
other = {'sector':'Other','total_assets':total_assets_by_sector[~total_assets_by_sector.sector.isin(financial_assets.sector)].sum()['total_assets']}

#Put Together
sector_data = financial_assets.append(other,ignore_index=True)

# %%
labels = sector_data['sector']
sizes = sector_data['total_assets']

_ = plt.figure(figsize=(7,7))
_ = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=270)
_ = plt.title('', size=15)
plt.savefig('4finance_vs_total_assets.png')

# %%
#Average all numeric values by sector
total_by_sector = companies.groupby('sector').sum().reset_index()

#Get Financial Row
total_financial = total_by_sector[total_by_sector.sector == 'Financials']['revenues']

# %%
#Financial Sector Revenue
financial_revenue = total_financial['revenues']

#All Other Revenue (Sum)
other_revenue = {'sector':'Other','total_assets': total_by_sector.revenues.sum() - financial_revenue}


#Put Together
sector_revenue_data = total_financial.append(other_revenue,ignore_index=True)

# %%
sector_revenue_data
# Out:
#        sector     rank  employees      hqzip  revenues  revchange   profits  \
# 0  Financials  20815.0  3161998.0  2880322.0  2067.607      216.2  228461.2
# 1       Other      NaN        NaN        NaN       NaN        NaN       NaN
#
#    prftchange      assets  totshequity  \
# 0      -147.4  26816588.0    2656485.6
# 1         NaN         NaN          NaN
#
#                                    total_assets
# 0                                           NaN
# 1  6    9988.267
# Name: revenues, dtype: float64

# %%
#Financial Sector Revenue
financial_revenue = avg_financial['revenues']

#All Other Revenue (Sum)
other = {'sector':'Other','total_assets':}

#Put Together
sector_data = financial_assets.append(other,ignore_index=True)

# %%
#Financial Sector Profits
financial_assets = total_assets_by_sector[total_assets_by_sector.sector == 'Financials']

#All Other Profits (Sum)
other = {'sector':'Other','total_assets':total_assets_by_sector[~total_assets_by_sector.sector.isin(financial_assets.sector)].sum()['total_assets']}

#Put Together
sector_data = financial_assets.append(other,ignore_index=True)

# %% [markdown]
# ### c) Average Assets by Sectors (w/ Outlier)

# %%
#Sum by sector 
average_assets_by_sector = companies.groupby(['sector']).mean()[['assets']].reset_index()
average_assets_by_sector.columns= ['sector','avg_assets']

# %%
#Merge New Feature
by_sector = by_sector.merge(average_assets_by_sector)

# %%
#Plot Total Assets by Sector
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='avg_assets', y='sector', data=average_assets_by_sector)
_ = plt.title('Average Assets by Sector (w/Outlier)', size=13)
_ = plt.xlabel('Assets', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('5average_assets_by_sector.png')

# %% [markdown]
# ### d) Average Assets by Sectors (No Outlier)

# %%
#Plot Average Assets by Sector
avg__assets_by_sector_no_outlier = average_assets_by_sector[average_assets_by_sector.sector != 'Financials']
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='avg_assets', y='sector', data=avg__assets_by_sector_no_outlier)
_ = plt.title('Average Assets by Sector (No Outlier)', size=13)
_ = plt.xlabel('Assets', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('6avg__assets_by_sector_no_outlier.png')

# %% [markdown]
# ## 2. Revenue by Sectors

# %% [markdown]
# ### a) Total Revenue by Sectors

# %%
#Sum by sector 
total_revenue_by_sector = companies.groupby(['sector'])[['revenues']].sum().reset_index()
total_revenue_by_sector.columns = ['sector','total_revenue']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_revenue_by_sector)

# %%
#Plot Total Assets by Sector
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_revenue', y='sector', data=total_revenue_by_sector)
_ = plt.title('Total Revenue by Sector', size=13)
_ = plt.xlabel('Revenue', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('7total_revenue_by_sector.png')

# %% [markdown]
# ### b) Average Revenue by Sector

# %%
#Mean by Sector
avg_revenue_by_sector = companies.groupby('sector')[['revenues']].mean().reset_index()
avg_revenue_by_sector.columns = ['sector','avg_revenues']

# %%
#Merge New Feature
by_sector = by_sector.merge(avg_revenue_by_sector)

# %%
#Plot Average Revenue by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='avg_revenues', y='sector', data=avg_revenue_by_sector)
_ = plt.title("Average Revenue by Sectors", size=13)
_ = plt.xlabel("Revenue", size=13)
_ = plt.ylabel("")
plt.savefig('8avg_revenue_by_sector.png')

# %% [markdown]
# ## 3. Revenue Change by Sector

# %% [markdown]
# ### a) Total Revenue Change by Sector

# %%
#Average Revenue Change
total_revchange_by_sector = companies.groupby(['sector'])[['revchange']].sum().reset_index()
total_revchange_by_sector.columns = ['sector','total_revchange']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_revchange_by_sector)

# %%
#Plot Total Revenue Change by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_revchange', y='sector', data=total_revchange_by_sector)
_ = plt.title("Total Revenue Change by Sectors", size=13)
_ = plt.xlabel("Revenue Change (%)", size=13)
_ = plt.ylabel("")
plt.savefig('9total_revchange_by_sector.png')

# %% [markdown]
# ### b) Average Revenue Change by Sector

# %%
#Average Revenue Change
avg_revchange_by_sector = companies.groupby(['sector'])[['revchange']].mean().reset_index()
avg_revchange_by_sector.columns = ['sector','avg_revchange']

# %%
#Merge New Feature
by_sector = by_sector.merge(avg_revchange_by_sector)

# %%
#Plot Average Revenue Change by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='avg_revchange', y='sector', data=avg_revchange_by_sector)
_ = plt.title("Average Revenue Change by Sectors", size=13)
_ = plt.xlabel("Revenue Change (%)", size=13)
_ = plt.ylabel("")
plt.savefig('10avg_revchange_by_sector.png')

# %% [markdown]
# ## 4. Profits by Sectors

# %% [markdown]
# ### a) Total Profit by Sector

# %%
#Sum by sector 
total_profits_by_sector = companies.groupby(['sector'])[['profits']].sum().reset_index()
total_profits_by_sector.columns = ['sector','total_profits']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_profits_by_sector)

# %%
#Plot Total Assets by Sector
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='total_profits', y='sector', data=total_profits_by_sector)
_ = plt.title('Total Profits by Sector', size=13)
_ = plt.xlabel('Profits', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('11total_profits_by_sector.png')

# %% [markdown]
# ### b) Average Profit by Sector

# %%
#Average by sector 
average_profit_by_sector = companies.groupby(['sector'])[['profits']].mean().reset_index()
average_profit_by_sector.columns = ['sector','avg_profits']

# %%
#Merge New Feature
by_sector = by_sector.merge(average_profit_by_sector)

# %%
#Plot Average Profit by Sector
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='avg_profits', y='sector', data=average_profit_by_sector)
_ = plt.title('Average Profits by Sector', size=13)
_ = plt.xlabel('Profits', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('12average_profit_by_sector.png')

# %% [markdown]
# ## 5. Profit Change (%) by Sector

# %%
companies['prftchange'] = companies['prftchange'].str.replace(",","")
companies['prftchange'] = pd.to_numeric(companies['prftchange'])

# %% [markdown]
# ### a) Total Profit Change by Sector

# %%
#Average Profit Change by Sector
total_prftchange_by_sector = companies.groupby(['sector'])[['prftchange']].sum().reset_index()
total_prftchange_by_sector.columns = ['sector','total_prftchange']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_prftchange_by_sector)

# %%
#Plot Average Profit Change by Sector
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='total_prftchange', y='sector', data=total_prftchange_by_sector)
_ = plt.title('Total Profits Change by Sector', size=13)
_ = plt.xlabel('Profits Change (%)', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('13total_prftchange_by_sector.png')

# %% [markdown]
# ### b) Average Profit Change by Sector

# %%
#Average Profit Change by Sector
avg_prftchange_by_sector = companies.groupby(['sector'])[['prftchange']].mean().reset_index()
avg_prftchange_by_sector.columns = ['sector','avg_prftchange']

# %%
#Merge New Feature
by_sector = by_sector.merge(avg_prftchange_by_sector)

# %%
#Plot Average Profit Change by Sector
_ = plt.figure(figsize=(8,6))
_ = sns.barplot(x='avg_prftchange', y='sector', data=avg_prftchange_by_sector)
_ = plt.title('Average Profits Change by Sector', size=13)
_ = plt.xlabel('Profits Change (%)', size=12)
_ = plt.ylabel('', size=12)
plt.savefig('14avg_prftchange_by_sector.png')

# %% [markdown]
# ## 4. Employees by Sector

# %% [markdown]
# ### a) Total Employees by Sector

# %%
#Total Employees by Sector
total_employees_by_sector = companies.groupby('sector')[['employees']].sum().reset_index()
total_employees_by_sector.columns = ['sector','total_employees']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_employees_by_sector)

# %%
#Plot Average Employees by Sector
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_employees', y='sector', data=total_employees_by_sector)
_ = plt.title("Total Employees by Sectors", size=13)
_ = plt.xlabel("Number of Employees", size=13)
_ = plt.ylabel("")
plt.savefig('15total_employees_by_sector.png')

# %% [markdown]
# ### b) Average Employees by Sector

# %%
#Average Employees by Sector
avg_employees_by_sector = companies.groupby('sector')[['employees']].mean().reset_index()
avg_employees_by_sector.columns = ['sector','avg_employees']

# %%
#Merge New Feature
by_sector = by_sector.merge(avg_employees_by_sector)

# %%
#Plot Average Employees by Sector
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='avg_employees', y='sector', data=avg_employees_by_sector)
_ = plt.title("Average Employees by Sectors", size=13)
_ = plt.xlabel("Number of Employees", size=13)
_ = plt.ylabel("")
plt.savefig('16avg_employees_by_sector.png')

# %% [markdown]
# ### c) Value Per Employee
# #### Potential Definitions Value:
# - <strong>By Revenue:</strong> Revenue Per Employee
# - <strong>By Profits:</strong> Profits Per Employee
# - <strong>By Assets:</strong> Assets Per Employee
#
# #### Final Verdict
# After analysis, concluded that definding Profits per Employee as the metric for Value is the best approach.
# - Value = Profit per Employee

# %%
#Average Profit by Sector
value_by_sector = companies.groupby('sector')[['revenues']].mean().reset_index()
value_by_sector.columns = ['sector','avg_revenue']

# %%
value_by_sector = value_by_sector.merge(avg_employees_by_sector)

# %%
value_by_sector['value_per_employee'] = value_by_sector.avg_revenue / value_by_sector.avg_employees
value_by_sector.head()
# Out:
#                 sector   avg_revenue  avg_employees  value_per_employee
# 0  Aerospace & Defense  28191.833333   71986.666667            0.391626
# 1              Apparel  13250.800000   50930.000000            0.260177
# 2    Business Services   9734.250000   42252.500000            0.230383
# 3            Chemicals  13476.214286   26064.714286            0.517029
# 4               Energy  20638.894737   15254.578947            1.352964

# %%
#Plot Average Revenue Change by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='value_per_employee', y='sector', data=value_by_sector)
_ = plt.title("Value Per Employee by Sectors", size=13)
_ = plt.xlabel("Value Per Employee", size=13)
_ = plt.ylabel("")
plt.savefig('17value_by_sector.png')

# %%
#Merge New Feature
by_sector = by_sector.merge(value_by_sector)

# %% [markdown]
# ## 5. Total Share Equity by Sector

# %% [markdown]
# ### a) Total Total Share Equity by Sector

# %%
#Total Total Share Equity by Sector
total_totshequity_by_sector = companies.groupby('sector')[['totshequity']].sum().reset_index()
total_totshequity_by_sector.columns = ['sector','total_ttshequity']

# %%
#Merge New Feature
by_sector = by_sector.merge(total_totshequity_by_sector)

# %%
#Plot Average Revenue Change by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='total_ttshequity', y='sector', data=total_totshequity_by_sector)
_ = plt.title("Total Total Share Equity by Sectors", size=13)
_ = plt.xlabel("Total Share Equity", size=13)
_ = plt.ylabel("")
plt.savefig('18total_totshequity_by_sector.png')

# %% [markdown]
# ### b) Average Total Share Equity by Sector

# %%
#Average Total Share Equity by Sector
avg_totshequity_by_sector = companies.groupby('sector')[['totshequity']].mean().reset_index()
avg_totshequity_by_sector.columns = ['sector','avg_totshequity']

# %%
#Merge New Feature
by_sector = by_sector.merge(avg_totshequity_by_sector)

# %%
#Plot Average Revenue Change by Secgtor
_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='avg_totshequity', y='sector', data=avg_totshequity_by_sector)
_ = plt.title("Average Total Share Equity by Sectors", size=13)
_ = plt.xlabel("Total Share Equity", size=13)
_ = plt.ylabel("")
plt.savefig('19average_totshequity_by_sector.png')

# %% [markdown]
# # Relationships by Sector/Industry

# %% [markdown]
# ### Correlation: Industry Averages

# %%
#Averages by Industry 
averages_by_industry = companies.groupby(['sector','industry']).mean().reset_index()

# %%
averages_by_industry.corr()
# Out:
#                  rank  employees     hqzip  revenues  revchange   profits  \
# rank         1.000000  -0.447959  0.154370 -0.723563   0.059320 -0.457452
# employees   -0.447959   1.000000 -0.054667  0.505136  -0.027139  0.188932
# hqzip        0.154370  -0.054667  1.000000  0.003991  -0.080587 -0.089231
# revenues    -0.723563   0.505136  0.003991  1.000000   0.040233  0.458731
# revchange    0.059320  -0.027139 -0.080587  0.040233   1.000000  0.163611
# profits     -0.457452   0.188932 -0.089231  0.458731   0.163611  1.000000
# prftchange  -0.024912   0.148352 -0.072896  0.016209   0.060046  0.107746
# assets      -0.245760  -0.018771 -0.210692  0.196988  -0.055018  0.347953
# totshequity -0.385628   0.027534  0.013811  0.416201  -0.017800  0.561182
#
#              prftchange    assets  totshequity
# rank          -0.024912 -0.245760    -0.385628
# employees      0.148352 -0.018771     0.027534
# hqzip         -0.072896 -0.210692     0.013811
# revenues       0.016209  0.196988     0.416201
# revchange      0.060046 -0.055018    -0.017800
# profits        0.107746  0.347953     0.561182
# prftchange     1.000000 -0.030659    -0.019345
# assets        -0.030659  1.000000     0.680533
# totshequity   -0.019345  0.680533     1.000000

# %% [markdown]
# # By Rank

# %% [markdown]
# ## 1. Employee vs Rank

# %% [markdown]
# ### a) Employees vs Rank (with Outlier)

# %%
_ = plt.figure(figsize=(8,5))
_ = plt.plot(companies['employees'], companies['rank'], linestyle='none', marker='.')
_ = plt.title("Employees vs Rank (with Outliers)", size=13)
_ = plt.xlabel("Number of Employees", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('20employees_v_rank.png')

# %% [markdown]
# ### b) Find Outlier

# %%
companies.sort_values('employees', ascending=False)[['ticker','fullname','employees']].head()
# Out:
#     ticker                                     fullname  employees
# 0      WMT                        Wal-Mart Stores, Inc.    2300000
# 17      KR                           The Kroger Company     443000
# 398   YUMC                     Yum China Holdings, Inc.     420000
# 31     IBM  International Business Machines Corporation     414400
# 22      HD                         The Home Depot, Inc.     406000

# %% [markdown]
# ### c) Employees vs Rank (No Outlier)

# %%
#Take Out Outlier
no_employee_outliers = companies[companies.ticker != 'WMT']

# %%
#Plot Employees without Outliers
_ = plt.figure(figsize=(8,5))
_ = plt.plot(no_employee_outliers['employees'], no_employee_outliers['rank'], linestyle='none', marker='.')
_ = plt.title("Employees vs Rank (No Outliers)", size=13)
_ = plt.xlabel("Number of Employees", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('21employees_v_rank_no_outlier.png')

# %% [markdown]
# ### Observation:
# - Lower Ranking, Less Employees, Lower Variance.
# - Higher Ranking, More Employees?, High Variance.

# %% [markdown]
# ## 2. Revenue vs Rank

# %%
_ = plt.figure(figsize=(8,5))
_ = plt.plot(companies['revenues'], companies['rank'], linestyle='none', marker='.')
_ = plt.title("Revenues vs Rank", size=13)
_ = plt.xlabel("Revenues", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('22revenue_v_rank.png')

# %% [markdown]
# ## 3. Profits vs Rank
#
# #### Observations
# - Negative, Non-linear Relationship
# - Lower Rank, Lower Profit, Lower Variance
# - Higher Rank, Higher Profit, Higher Variance

# %%
_ = plt.figure(figsize=(8,5))
_ = plt.plot(companies['profits'], companies['rank'], linestyle='none', marker='.')
_ = plt.title("Profits vs Rank", size=13)
_ = plt.xlabel("Profits", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('23profits_v_rank.png')

# %% [markdown]
# ## 5. Assets vs Rank

# %%
_ = plt.figure(figsize=(8,5))
_ = plt.plot(companies['assets'], companies['rank'], linestyle='none', marker='.')
_ = plt.title("Assets vs Rank", size=13)
_ = plt.xlabel("Assets", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('24assets_v_rank.png')

# %% [markdown]
# ## 6. Total Share Equity vs Rank

# %%
_ = plt.figure(figsize=(8,5))
_ = plt.plot(companies['totshequity'], companies['rank'], linestyle='none', marker='.')
_ = plt.title("Total Share Equity vs Rank", size=13)
_ = plt.xlabel("Total Share Equity", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('25totshequity_v_rank.png')

# %%
#Plot Employees without Outliers
_ = plt.figure(figsize=(8,5))
_ = plt.plot(no_employee_outliers['employees'], no_employee_outliers['rank'], linestyle='none', marker='.')
_ = plt.title("Employees vs Rank (with Outliers)", size=13)
_ = plt.xlabel("Number of Employees", size=13)
_ = plt.ylabel("Fortune Ranking")
plt.savefig('25totshequity_v_rank.png')

# %%
averages_by_industry.head()
# Out:
#                 sector                          industry        rank  \
# 0  Aerospace & Defense             Aerospace and Defense  201.333333
# 1              Apparel                           Apparel  291.200000
# 2    Business Services            Advertising, Marketing  262.000000
# 3    Business Services  Diversified Outsourcing Services  310.666667
# 4    Business Services           Financial Data Services  338.555556
#
#        employees         hqzip      revenues  revchange      profits  \
# 0   71986.666667  25020.500000  28191.833333  -3.208333  2093.308333
# 1   50930.000000  34311.200000  13250.800000   1.940000  1263.700000
# 2   64150.000000  10022.000000  11632.000000   2.500000   878.550000
# 3  128083.333333  12060.333333  10409.666667  -0.166667   612.500000
# 4   21544.444444  53431.111111   9028.000000  11.088889  1804.888889
#
#    prftchange        assets  totshequity
# 0    8.050000  31897.666667  6425.750000
# 1   -3.960000  11064.800000  5394.400000
# 2   19.450000  17825.000000  2089.500000
# 3   -0.066667  18844.333333  2539.000000
# 4   -4.488889  26164.666667  7776.888889

# %%
companies
# Out:
#      rank                               title  \
# 0       1                             Walmart
# 1       2                  Berkshire Hathaway
# 2       3                               Apple
# 3       4                         Exxon Mobil
# 4       5                            McKesson
# 5       6                  UnitedHealth Group
# 6       7                          CVS Health
# 7       8                      General Motors
# 8       9                                AT&T
# 9      10                          Ford Motor
# 10     11                   AmerisourceBergen
# 11     12                          Amazon.com
# 12     13                    General Electric
# 13     14                             Verizon
# 14     15                     Cardinal Health
# 15     16                              Costco
# 16     17            Walgreens Boots Alliance
# 17     18                              Kroger
# 18     19                             Chevron
# 19     20                          Fannie Mae
# 20     21                   J.P. Morgan Chase
# 21     22             Express Scripts Holding
# 22     23                          Home Depot
# 23     24                              Boeing
# 24     25                         Wells Fargo
# 25     26               Bank of America Corp.
# 26     27                            Alphabet
# 27     28                           Microsoft
# 28     29                              Anthem
# 29     30                           Citigroup
# ..    ...                                 ...
# 470   471                              Fiserv
# 471   472               Host Hotels & Resorts
# 472   473                 Insight Enterprises
# 473   474                              Mattel
# 474   475          AmTrust Financial Services
# 475   476                Cincinnati Financial
# 476   477                Simon Property Group
# 477   478                       Western Union
# 478   479                             KeyCorp
# 479   480                   Delek US Holdings
# 480   481         Booz Allen Hamilton Holding
# 481   482                            Chemours
# 482   483  Western & Southern Financial Group
# 483   484                            Celanese
# 484   485                 Windstream Holdings
# 485   486                            Seaboard
# 486   487                           Essendant
# 487   488                              Apache
# 488   489                              Airgas
# 489   490                      Kelly Services
# 490   491                       Liberty Media
# 491   492                    Rockwell Collins
# 492   493           Robert Half International
# 493   494                           CH2M Hill
# 494   495                            Big Lots
# 495   496                       Michaels Cos.
# 496   497                       Toll Brothers
# 497   498                               Yahoo
# 498   499                       Vistra Energy
# 499   500                      ABM Industries
#
#                                    website  employees  \
# 0                   http://www.walmart.com    2300000
# 1         http://www.berkshirehathaway.com     367700
# 2                     http://www.apple.com     116000
# 3                http://www.exxonmobil.com      72700
# 4                  http://www.mckesson.com      68000
# 5         http://www.unitedhealthgroup.com     230000
# 6                 http://www.cvshealth.com     204000
# 7                        http://www.gm.com     225000
# 8                       http://www.att.com     268540
# 9                      http://www.ford.com     201000
# 10        http://www.amerisourcebergen.com      18500
# 11                   http://www.amazon.com     341400
# 12                       http://www.ge.com     295000
# 13                  http://www.verizon.com     160900
# 14           http://www.cardinalhealth.com      37300
# 15                   http://www.costco.com     172000
# 16   http://www.walgreensbootsalliance.com     300000
# 17              http://www.thekrogerco.com     443000
# 18                  http://www.chevron.com      55200
# 19                http://www.fanniemae.com       7000
# 20            http://www.jpmorganchase.com     243355
# 21          http://www.express-scripts.com      25600
# 22                http://www.homedepot.com     406000
# 23                   http://www.boeing.com     150540
# 24               http://www.wellsfargo.com     269100
# 25            http://www.bankofamerica.com     208024
# 26                      http://www.abc.xyz      72053
# 27                http://www.microsoft.com     114000
# 28                http://www.antheminc.com      53000
# 29                http://www.citigroup.com     219000
# ..                                     ...        ...
# 470                  http://www.fiserv.com      23000
# 471              http://www.hosthotels.com        220
# 472                 http://www.insight.com       5930
# 473                  http://www.mattel.com      32000
# 474            http://www.amtrustgroup.com       8000
# 475                  http://www.cinfin.com       4754
# 476                   http://www.simon.com       4050
# 477            http://www.westernunion.com      10700
# 478                     http://www.key.com      15700
# 479                 http://www.delekus.com       1326
# 480               http://www.boozallen.com      22600
# 481                http://www.chemours.com       7000
# 482         http://www.westernsouthern.com       2178
# 483                http://www.celanese.com       7293
# 484              http://www.windstream.com      11870
# 485            http://www.seaboardcorp.com      11781
# 486               http://www.essendant.com       6600
# 487              http://www.apachecorp.com       3727
# 488                  http://www.airgas.com      17000
# 489           http://www.kellyservices.com       7500
# 490            http://www.libertymedia.com       3626
# 491         http://www.rockwellcollins.com      19000
# 492              http://www.roberthalf.com      16400
# 493                    http://www.ch2m.com      20000
# 494                 http://www.biglots.com      23150
# 495                http://www.michaels.com      31000
# 496            http://www.tollbrothers.com       4200
# 497                   http://www.yahoo.com       8500
# 498            http://www.vistraenergy.com       4431
# 499                     http://www.abm.com     110000
#
#                          sector  \
# 0                     Retailing
# 1                    Financials
# 2                    Technology
# 3                        Energy
# 4                   Wholesalers
# 5                   Health Care
# 6                   Health Care
# 7        Motor Vehicles & Parts
# 8            Telecommunications
# 9        Motor Vehicles & Parts
# 10                  Wholesalers
# 11                   Technology
# 12                  Industrials
# 13           Telecommunications
# 14                  Wholesalers
# 15                    Retailing
# 16           Food & Drug Stores
# 17           Food & Drug Stores
# 18                       Energy
# 19                   Financials
# 20                   Financials
# 21                  Health Care
# 22                    Retailing
# 23          Aerospace & Defense
# 24                   Financials
# 25                   Financials
# 26                   Technology
# 27                   Technology
# 28                  Health Care
# 29                   Financials
# ..                          ...
# 470           Business Services
# 471                  Financials
# 472                 Wholesalers
# 473          Household Products
# 474                  Financials
# 475                  Financials
# 476                  Financials
# 477           Business Services
# 478                  Financials
# 479                      Energy
# 480                  Technology
# 481                   Chemicals
# 482                  Financials
# 483                   Chemicals
# 484          Telecommunications
# 485   Food, Beverages & Tobacco
# 486                 Wholesalers
# 487                      Energy
# 488                 Wholesalers
# 489           Business Services
# 490                       Media
# 491         Aerospace & Defense
# 492           Business Services
# 493  Engineering & Construction
# 494                   Retailing
# 495                   Retailing
# 496  Engineering & Construction
# 497                  Technology
# 498                      Energy
# 499           Business Services
#
#                                           industry         hqlocation  \
# 0                            General Merchandisers    Bentonville, AR
# 1         Insurance: Property and Casualty (Stock)          Omaha, NE
# 2                      Computers, Office Equipment      Cupertino, CA
# 3                               Petroleum Refining         Irving, TX
# 4                         Wholesalers: Health Care  San Francisco, CA
# 5          Health Care: Insurance and Managed Care     Minnetonka, MN
# 6         Health Care: Pharmacy and Other Services     Woonsocket, RI
# 7                         Motor Vehicles and Parts        Detroit, MI
# 8                               Telecommunications         Dallas, TX
# 9                         Motor Vehicles and Parts       Dearborn, MI
# 10                        Wholesalers: Health Care   Chesterbrook, PA
# 11                 Internet Services and Retailing        Seattle, WA
# 15                999 Lake Dr.       Issaquah      WA     ...
# 16              108 Wilmot Rd.      Deerfield      IL     ...
# 17               1014 Vine St.     Cincinnati      OH     ...
# 18   6001 Bollinger Canyon Rd.      San Ramon      CA     ...
# 19    3900 Wisconsin Ave. N.W.     Washington      DC     ...
# 20               270 Park Ave.       New York      NY     ...
# 21               1 Express Way      St. Louis      MO     ...
# 22        2455 Paces Ferry Rd.        Atlanta      GA     ...
# 23      100 N. Riverside Plaza        Chicago      IL     ...
# 24          420 Montgomery St.  San Francisco      CA     ...
# 25            100 N. Tryon St.      Charlotte      NC     ...
# 26     1600 Amphitheatre Pkwy.  Mountain View      CA     ...
# 27             1 Microsoft Way        Redmond      WA     ...
# 28         120 Monument Circle   Indianapolis      IN     ...
# 29           388 Greenwich St.       New York      NY     ...
# ..                         ...            ...     ...     ...
# 470             255 Fiserv Dr.     Brookfield      WI     ...
# 471         6903 Rockledge Dr.       Bethesda      MD     ...
# 472          6820 S. Harl Ave.          Tempe      AZ     ...
# 473      333 Continental Blvd.     El Segundo      CA     ...
# 474             59 Maiden Lane       New York      NY     ...
# 475        6200 S. Gilmore Rd.      Fairfield      OH     ...
# 476      225 W. Washington St.   Indianapolis      IN     ...
# 477      12500 E. Belford Ave.      Englewood      CO     ...
# 478             127 Public Sq.      Cleveland      OH     ...
# 479          7102 Commerce Way      Brentwood      TN     ...
# 480        8283 Greensboro Dr.         McLean      VA     ...
# 481            1007 Market St.     Wilmington      DE     ...
# 482               400 Broadway     Cincinnati      OH     ...
# 483   222 W. Las Colinas Blvd.         Irving      TX     ...
# 484     4001 Rodney Parham Rd.    Little Rock      AR     ...
# 485           9000 W. 67th St.        Merriam      KS     ...
# 486         1 Parkway N. Blvd.      Deerfield      IL     ...
# 487        2000 Post Oak Blvd.        Houston      TX     ...
# 488  259 N. Radnor-Chester Rd.         Radnor      PA     ...
# 489      999 W. Big Beaver Rd.           Troy      MI     ...
# 490        12300 Liberty Blvd.      Englewood      CO     ...
# 491       400 Collins Rd. N.E.   Cedar Rapids      IA     ...
# 492         2884 Sand Hill Rd.     Menlo Park      CA     ...
# 493        9191 S. Jamaica St.      Englewood      CO     ...
# 494           300 Phillipi Rd.       Columbus      OH     ...
# 495       8000 Bent Branch Dr.         Irving      TX     ...
# 496          250 Gibraltar Rd.        Horsham      PA     ...
# 497             701 First Ave.      Sunnyvale      CA     ...
# 498             1601 Bryan St.         Dallas      TX     ...
# 499            1 Liberty Plaza       New York      NY     ...
#
#                                          ceo-title  \
# 0    President, Chief Executive Officer & Director
# 1               Chairman & Chief Executive Officer
# 2               Chief Executive Officer & Director
# 3               Chairman & Chief Executive Officer
# 4    Chairman, President & Chief Executive Officer
# 5               Chief Executive Officer & Director
# 6    President, Chief Executive Officer & Director
# 7               Chairman & Chief Executive Officer
# 8    Chairman, President & Chief Executive Officer
# 9    President, Chief Executive Officer & Director
# 10   Chairman, President & Chief Executive Officer
# 11   Chairman, President & Chief Executive Officer
# 12              Chairman & Chief Executive Officer
# 13              Chairman & Chief Executive Officer
# 14              Chairman & Chief Executive Officer
# 15   President, Chief Executive Officer & Director
# 16         -1.1    72688      29880.0
# 17         -3.1    36505       6698.0
# 18       -110.8   260078     145556.0
# 19         12.4  3287968       6071.0
# 20          1.2  2490972     254190.0
# 21         37.5    51745      16236.0
# 22         13.5    42966       4333.0
# 23         -5.4    89997        817.0
# 24         -4.2  1930115     199581.0
# 25         12.7  2187702     266840.0
# 26         19.1   167497     139036.0
# 27         37.8   193694      71997.0
# 28         -3.5    65083      25100.0
# 29        -13.5  1792077     225120.0
# ..          ...      ...          ...
# 470        30.6     9743       2541.0
# 471        36.6    11408       6994.0
# 472        11.7     2219        713.0
# 473       -13.9     6494       2408.0
# 474        -8.8    22615       3269.0
# 475        -6.8    20386       7060.0
# 476         0.6    31104       4310.0
# 477       -69.8     9420        902.0
# 478       -13.6   136453      15240.0
# 479      -892.3     2985        992.0
# 480        26.5     3010        409.0
# 481        26.5     6060        100.0
# 482       -47.2    43831       5104.0
# 483       196.1     8357       2588.0
# 484     -1499.6    11770        170.0
# 485        82.5     4755       3162.0
# 486        82.5     2164        781.0
# 487        82.5    22519       6238.0
# 488        -8.3     6135       2045.0
# 489       124.5     2028       1012.0
# 490       962.5    31377      11756.0
# 491         6.1     7707       2078.0
# 492        -4.0     1778       1087.0
# 493       -81.3     2671        547.0
# 494         7.0     1608        651.0
# 495         4.2     2148      -1698.0
# 496         5.2     9737       4229.0
# 497         5.2    48083      31049.0
# 498         5.2    15167       6597.0
# 499       -25.0     2281        974.0
#
# [500 rows x 23 columns]

# %% [markdown]
# # Interesting Features

# %% [markdown]
# ## Looking at Revenue

# %%
companies.sort_values('revchange', ascending=False).head()
# Out:
#      rank                   title                        website  employees  \
# 95     96  Charter Communications         http://www.charter.com      91500
# 207   208           Newell Brands    http://www.newellbrands.com      53400
# 48     49         Albertsons Cos.      http://www.albertsons.com     274000
# 466   467                    Olin            http://www.olin.com       6400
# 426   427         TreeHouse Foods  http://www.treehousefoods.com      16027
#
#                         sector                     industry     hqlocation  \
# 95          Telecommunications           Telecommunications   Stamford, CT
# 207         Household Products  Home Equipment, Furnishings    Hoboken, NJ
# 48          Food & Drug Stores         Food and Drug Stores      Boise, ID
# 466                  Chemicals                    Chemicals    Clayton, MO
# 426  Food, Beverages & Tobacco       Food Consumer Products  Oak Brook, IL
#
#                    hqaddr     hqcity hqstate     ...       \
# 95       400 Atlantic St.   Stamford      CT     ...
# 207         221 River St.    Hoboken      NJ     ...
# 48   250 Parkcenter Blvd.      Boise      ID     ...
# 466  190 Carondelet Plaza    Clayton      MO     ...
# 426       2021 Spring Rd.  Oak Brook      IL     ...
#
#                                          ceo-title  \
# 95              Chairman & Chief Executive Officer
# 207             Chief Executive Officer & Director
# 48              Chairman & Chief Executive Officer
# 466  President, Chief Executive Officer & Director
# 426             Chairman & Chief Executive Officer
#
#                                      address ticker  \
# 95      400 Atlantic St., Stamford, CT 06901   CHTR
# 207         221 River St., Hoboken, NJ 07030    NWL
# 48     250 Parkcenter Blvd., Boise, ID 83706    PRU
# 466  190 Carondelet Plaza, Clayton, MO 63105    OLN
# 426     2021 Spring Rd., Oak Brook, IL 60523    THS
#
#                          fullname revenues revchange profits  prftchange  \
# 95   Charter Communications, Inc.    29003     197.3  3522.0         2.4
# 207            Newell Brands Inc.    13264     122.1   527.8        50.8
# 48     Albertsons Companies, Inc.    58734     115.9  -502.2       -22.6
# 466              Olin Corporation     5551      94.5    -3.9       -16.2
# 426         TreeHouse Foods, Inc.     6175      92.6  -228.6      -298.9
#
#      assets  totshequity
# 95   149067      40139.0
# 207   33838      11349.0
# 48    23770       1613.0
# 466    8763       2273.0
# 426    6546       2503.0
#
# [5 rows x 23 columns]

# %%
_ = plt.hist(companies.revchange, bins=50)
_ = plt.title('Revenue Change Distribution')
_ = plt.xlabel('Revenue Change')
_ = plt.ylabel('Frequency')

# %%
_ = plt.plot(companies.revchange, companies.revenues, linestyle='none', marker='.')

# %%
companies[finance].head()
# Out:
#   ticker                 fullname  revenues  revchange  profits prftchange  \
# 0    WMT    Wal-Mart Stores, Inc.    485873        0.8  13643.0       -7.2
# 1   BRKA  Berkshire Hathaway Inc.    223604        6.1  24074.0          0
# 2   AAPL              Apple, Inc.    215639       -7.7  45687.0      -14.4
# 3    XOM  Exxon Mobil Corporation    205004      -16.7   7840.0      -51.5
# 4    MCK     McKesson Corporation    192487        6.2   2258.0         53
#
#    assets  totshequity
# 0  198825      77798.0
# 1  620854     283001.0
# 2  321686     128249.0
# 3  330314     167325.0
# 4   56563       8924.0

# %%
companies[info].head()
# Out:
#   ticker                 fullname                  ceo  employees  \
# 0    WMT    Wal-Mart Stores, Inc.  C. Douglas McMillon    2300000
# 1   BRKA  Berkshire Hathaway Inc.    Warren E. Buffett     367700
# 2   AAPL              Apple, Inc.      Timothy D. Cook     116000
# 3    XOM  Exxon Mobil Corporation      Darren W. Woods      72700
# 4    MCK     McKesson Corporation   John H. Hammergren      68000
#
#         sector                                  industry         hqcity  \
# 0    Retailing                     General Merchandisers    Bentonville
# 1   Financials  Insurance: Property and Casualty (Stock)          Omaha
# 2   Technology               Computers, Office Equipment      Cupertino
# 3       Energy                        Petroleum Refining         Irving
# 4  Wholesalers                  Wholesalers: Health Care  San Francisco
#
#   hqstate  hqzip         hqtel
# 0      AR  72716  479-273-4000
# 1      NE  68131  402-346-1400
# 2      CA  95014  408-996-1010
# 3      TX  75039  972-444-1000
# 4      CA  94104  415-983-8300

# %% [markdown]
# ### Top 10 Fortune 500 Zipcodes

# %%
top_10_zipcodes = pd.DataFrame(companies.hqzip.value_counts()).reset_index().head(10)
top_10_zipcodes.columns = ['zipcode','count']

'''_ = plt.figure(figsize=(8,7))
_ = sns.barplot(x='zipcode', y='count', data=top_10_zipcodes)
_ = plt.title("Top 10 Fortune 500 Zipcodes", size=13)
_ = plt.xlabel("Count", size=13)
_ = plt.ylabel("")'''
# Out:
# '_ = plt.figure(figsize=(8,7))\n_ = sns.barplot(x=\'zipcode\', y=\'count\', data=top_10_zipcodes)\n_ = plt.title("Top 10 Fortune 500 Zipcodes", size=13)\n_ = plt.xlabel("Count", size=13)\n_ = plt.ylabel("")'

# %%
companies[companies.title.str.contains('racle')].ceo
# Out:
# 80    Safra A. Catz, Mark V. Hurd
# Name: ceo, dtype: object
